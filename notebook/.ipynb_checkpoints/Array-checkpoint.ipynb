# %%
scores_list = [65,70,85,90,75]

scores_list+5
# Out:
#    math  english
# 0    70       68
# 1    85       88
# 2    78       75
# 3    90       92

# %%
new_scores = []
for s in scores_list:
    new_scores.append(s+5)
new_scores
# Out:
# [70, 75, 90, 95, 80]

# %%
import numpy as np

scores = np.array([65,70,85,90,75])

scores+5
# Out:
# array([70, 75, 90, 95, 80])

# %%
scores.shape
# Out:
# (5,)

# %%
scores.size
# Out:
# 5

# %%
scores.dtype
# Out:
# dtype('int64')

# %%
scores2 = np.array([
    [80,90,100],
    [60,50,90],
    [60,50,90]
])

print(scores2.shape,"\n", scores2.size,"\n",scores2.dtype)
# Out:
# (3, 3)
#  9
#  int64

# %%
print(scores)
scores[:1]
# Out:
# [65 70 85 90 75]
# array([65])

# %%
scores[scores>75]
# Out:
# array([85, 90])

# %%
np.mean(scores)
# Out:
# np.float64(77.0)

# %%
np.median(scores)
# Out:
# np.float64(75.0)

# %%
A = np.array([68,69,70,71,72])
B = np.array([40,50,70,90,100])

np.mean(A),np.mean(B)
# Out:
# (np.float64(70.0), np.float64(70.0))

# %%
np.std(A),np.std(B)
# Out:
# (np.float64(1.4142135623730951), np.float64(22.80350850198276))

# %%
import pandas as pd

df = pd.DataFrame({
    "math":[70,85,78,90],
    "english":[68,88,75,92]
})
df
# Out:
#    math  english
# 0    70       68
# 1    85       88
# 2    78       75
# 3    90       92

# %%
df.head(2)
# Out:
#    math  english
# 0    70       68
# 1    85       88

# %%
df.shape
# Out:
# (4, 2)

# %%
df.columns
# Out:
# Index(['math', 'english'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   math     4 non-null      int64
#  1   english  4 non-null      int64
# dtypes: int64(2)
# memory usage: 196.0 bytes

# %%
df.describe()
# Out:
#             math    english
# count   4.000000   4.000000
# mean   80.750000  80.750000
# std     8.693868  11.176612
# min    70.000000  68.000000
# 25%    76.000000  73.250000
# 50%    81.500000  81.500000
# 75%    86.250000  89.000000
# max    90.000000  92.000000

# %%
df["math"]
# Out:
# 0    70
# 1    85
# 2    78
# 3    90
# Name: math, dtype: int64

# %%
df[["math","english"]]
# Out:
#    math  english
# 0    70       68
# 1    85       88
# 2    78       75
# 3    90       92

# %%
df["average"] = (df["math"]+df["english"])/2
df
# Out:
#    math  english  average
# 0    70       68     69.0
# 1    85       88     86.5
# 2    78       75     76.5
# 3    90       92     91.0

# %%
df[df["average"]>=75]
# Out:
#    math  english  average
# 1    85       88     86.5
# 2    78       75     76.5
# 3    90       92     91.0

# %%
df[df["average"]<=90]
# Out:
#    math  english  average
# 0    70       68     69.0
# 1    85       88     86.5
# 2    78       75     76.5
