# %%
#Importation of Necessary Libraries
import pandas as pd #Pandas use for dataframe manipulation 
import matplotlib as pl #Matplotlib use for data visualisation
import numpy as np #Numpy use for table , array manipulation

# %%
#Import csv dataFrame and display it
df = pd.read_csv(f'../data/heart-failure-prediction.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
#Display 5 first rows of the table dataFrame
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
#Display only values about Age column
df["Age"]
# Out:
# 0      40
# 1      49
# 2      37
# 3      48
# 4      54
#        ..
# 913    45
# 914    68
# 915    57
# 916    57
# 917    38
# Name: Age, Length: 918, dtype: int64

# %%
df["Age"].describe()
# Out:
# count    918.000000
# mean      53.510893
# std        9.432617
# min       28.000000
# 25%       47.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Sex']
# Out:
# 0      M
# 1      F
# 2      M
# 3      F
# 4      M
#       ..
# 913    M
# 914    M
# 915    M
# 916    F
# 917    M
# Name: Sex, Length: 918, dtype: object

# %%
df['Sex'].value_counts(normalize=True) * 100
# Out:
# Sex
# M    78.976035
# F    21.023965
# Name: proportion, dtype: float64

# %%
np.round(df['Sex'].value_counts(normalize=True) * 100,2)
# Out:
# Sex
# M    78.98
# F    21.02
# Name: proportion, dtype: float64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',legend=True)
# Out:
# <Axes: ylabel='count'>

# %%
df['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
df['ChestPainType'].value_counts().plot(kind='bar',legend = True)
# Out:
# <Axes: xlabel='ChestPainType'>
