# %%
scores_list = [65,70,85,90,75]

scores_list+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 scores_list = [65,70,85,90,75]
# ----> 3 scores_list+5
#
# TypeError: can only concatenate list (not "int") to list

# %%
new_scores = []
for s in scores_list:
    new_scores.append(s+5)
new_scores
# Out:
# [70, 75, 90, 95, 80]

# %%
import numpy as np

scores = np.array([65,70,85,90,75])

scores+5
# Out:
# array([70, 75, 90, 95, 80])

# %%
scores.shape
# Out:
# (5,)

# %%
scores.size
# Out:
# 5

# %%
scores.dtype
# Out:
# dtype('int64')

# %%
scores2 = np.array([
    [80,90,100],
    [60,50,90]
])

print(scores2.shape,"\n", scores2.size,"\n",scores2.dtype)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 scores2 = np.array([
#       2     [80,90,100],
#       3     [60,50]
#       4 ])
#       6 print(scores2.shape,"\n", scores2.size,"\n",scores2.dtype)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
